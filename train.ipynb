# %%
# %%bash
# uv run python scripts/data_prep/convert_xtc_to_cif_lynxkite.py \
#    --data_root /data/GROMACS \
#    --outdir /data/converted_trajectories \
#    --target_split all \
#    --num_workers 100 \
#    --frame_stride 10
# Out:
# Discovered 25 total trajectory jobs.
# Selected 25 trajectory jobs for conversion.
# Split manifests: /data/converted_trajectories/splits/lynxkite_train.csv and /data/converted_trajectories/splits/lynxkite_test.csv
# No-topology skipped trajectories: 0
# Converting trajectories: 100%|██████████| 25/25 [01:33<00:00,  3.74s/it]
# Done. Success: 24, Failed: 1
# Train mmCIF list: /data/converted_trajectories/splits/lynxkite_train_mmcif.txt
# Test mmCIF list: /data/converted_trajectories/splits/lynxkite_test_mmcif.txt
# Wrote error report: /data/converted_trajectories/splits/lynxkite_conversion_errors.txt

# %%
# %%bash
# export PYTHONPATH=.
# uv run python scripts/data_prep/prepare_training_data.py \
#     -i /data/converted_trajectories/splits/lynxkite_test_mmcif.txt \
#     -o /data/converted_trajectories/indices_test.csv \
#     -b /data/converted_trajectories/mmcif_bioassembly_test \
#     -d Atlas \
#     -n 100
# uv run python scripts/data_prep/prepare_training_data.py \
#     -i /data/converted_trajectories/splits/lynxkite_train_mmcif.txt \
#     -o /data/converted_trajectories/indices_train.csv \
#     -b /data/converted_trajectories/mmcif_bioassembly_train \
#     -d Atlas \
#     -n 100
# Out:
# Try to find the ccd cache data in the code directory for inference.
#   0%|          | 0/606 [00:00<?, ?it/s]
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.Try to find the ccd cache data in the code directory for inference.
#
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.Try to find the ccd cache data in the code directory for inference.
#
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.Try to find the ccd cache data in the code directory for inference.
#
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.Try to find the ccd cache data in the code directory for inference.
#
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
#  89%|████████▉ | 538/606 [00:21<00:01, 64.56it/s]2026-07-23 16:15:02,181 [/home/daniel/BioKinema/protenix/data/parser.py:3237] WARNING protenix.data.parser: Two mols have entity_ids and same number of atoms, but diff atom name:
# query_atom=Atom(np.array([ 49.81,  67.  , 125.21], dtype=float32), chain_id="3", res_id=346, ins_code="", res_name="LIG", hetero=False, atom_name="O2", element="O", auth_asym_id="A", auth_seq_id="346", label_seq_id="346", label_entity_id="1", label_alt_id=".", label_asym_id="A", is_resolved=True, mol_type="ligand", centre_atom_mask=1, chain_mol_type="protein", is_ligand=0, is_dna=0, is_rna=0, is_protein=1, distogram_rep_atom_mask=1, plddt_m_rep_atom_mask=0, cano_seq_resname="UNK", tokatom_idx=0, modified_res_mask=0, asym_id_int=3, entity_id_int=0, sym_id_int=3, mol_id=6)
#   ref_atom=Atom(np.array([ 47.79,  65.38, 126.39], dtype=float32), chain_id="3", res_id=346, ins_code="", res_name="LIG", hetero=False, atom_name="O1", element="O", auth_asym_id="A", auth_seq_id="346", label_seq_id="346", label_entity_id="1", label_alt_id=".", label_asym_id="A", is_resolved=True, mol_type="ligand", centre_atom_mask=1, chain_mol_type="protein", is_ligand=0, is_dna=0, is_rna=0, is_protein=1, distogram_rep_atom_mask=1, plddt_m_rep_atom_mask=0, cano_seq_resname="UNK", tokatom_idx=0, modified_res_mask=0, asym_id_int=3, entity_id_int=0, sym_id_int=3, mol_id=5)
# 100%|██████████| 606/606 [00:22<00:00, 27.14it/s]
# Try to find the ccd cache data in the code directory for inference.
#   0%|          | 0/1818 [00:00<?, ?it/s]
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
#
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.Try to find the ccd cache data in the code directory for inference.
#
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# Try to find the ccd cache data in the code directory for inference.
# 100%|██████████| 1818/1818 [00:40<00:00, 44.57it/s]

# %%
# %%bash
# export BIOKINEMA_INIT_CKPT=./checkpoints/BioKinema_atlas+misato+mdposit_sqrt.pt
# export CUTLASS_PATH=DS_USE_CUTLASS_PYTHON_BINDINGS
# mkdir /data/converted_trajectories/pairformer_emb_{test,train}
# CUDA_VISIBLE_DEVICES=0 uv run bash scripts/encode_embeddings.sh lynxkite_test 0 1
# CUDA_VISIBLE_DEVICES=0 uv run bash scripts/encode_embeddings.sh lynxkite_train 0 1
# Out:
# mkdir: cannot create directory ‘/data/converted_trajectories/pairformer_emb_test’: File exists
# mkdir: cannot create directory ‘/data/converted_trajectories/pairformer_emb_train’: File exists
# Try to find the ccd cache data in the code directory for inference.
# 2026-07-23 16:22:36,863 [/home/daniel/BioKinema/./runner/train.py:117] INFO root: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-07-23 16:22:36,863 [/home/daniel/BioKinema/./runner/train.py:127] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-07-23 16:22:36,864 [/home/daniel/BioKinema/./runner/train.py:150] INFO root: Finished init ENV.
# env: DS_USE_CUTLASS_PYTHON_BINDINGS
# 2026-07-23 16:22:36,910 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Using run name: encode_lynxkite_test_20260723_162236, run dir: ./output_encode/encode_lynxkite_test_20260723_162236, checkpoint_dir: ./output_encode/encode_lynxkite_test_20260723_162236/checkpoints, prediction_dir: ./output_encode/encode_lynxkite_test_20260723_162236/predictions, structure_dir: ./output_encode/encode_lynxkite_test_20260723_162236/structures, error_dir: ./output_encode/encode_lynxkite_test_20260723_162236/errors
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# /home/daniel/BioKinema/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2026-07-23 16:22:43,694 [/home/daniel/BioKinema/protenix/model/loss.py:2114] INFO protenix.model.loss: [Loss.__init__] tica_dynamics_loss=True, alpha_tica_dynamics=0.1, tica_cfg=temperature: 2.0
# weight_autocorrelation: 0.0
# weight_population: 1.0
# weight_transition: 0.5
#
# 2026-07-23 16:22:43,694 [/home/daniel/BioKinema/protenix/data/dataset.py:2508] INFO protenix.data.dataset: Using train sets ['lynxkite_test']
# lynxkite_test /data/converted_trajectories/pairformer_emb_test None
# 2026-07-23 16:22:43,885 [/home/daniel/BioKinema/protenix/data/dataset.py:527] INFO protenix.data.dataset: #Rows in indices list: 6094
# 2026-07-23 16:22:43,885 [/home/daniel/BioKinema/protenix/data/dataset.py:614] INFO protenix.data.dataset: ---------- Dataset lynxkite_test----------
# 2026-07-23 16:22:43,913 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: prot_prot: 3367/6094(55.25%)
# 2026-07-23 16:22:43,913 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: intra_prot: 2727/6094(44.75%)
# 2026-07-23 16:22:43,913 [/home/daniel/BioKinema/protenix/data/dataset.py:631] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:22:43,915 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: prot_prot: 2/4(50.0%)
# 2026-07-23 16:22:43,916 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: intra_prot: 2/4(50.0%)
# 2026-07-23 16:22:43,917 [/home/daniel/BioKinema/protenix/data/dataset.py:637] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:22:43,917 [/home/daniel/BioKinema/protenix/data/dataset.py:639] INFO protenix.data.dataset: Final pdb ids: 606
# 2026-07-23 16:22:43,917 [/home/daniel/BioKinema/protenix/data/dataset.py:640] INFO protenix.data.dataset: ------------------------------
# token_crop_size 1000
# --- WeightedMultiDataset Initialization ---
#   - Dataset 'lynxkite_test':
#     Dataset size: 6, Dataset Weight: 1.0
# lynxkite_test /data/converted_trajectories/pairformer_emb_test None
# 2026-07-23 16:22:44,096 [/home/daniel/BioKinema/protenix/data/dataset.py:527] INFO protenix.data.dataset: #Rows in indices list: 6094
# 2026-07-23 16:22:44,096 [/home/daniel/BioKinema/protenix/data/dataset.py:614] INFO protenix.data.dataset: ---------- Dataset lynxkite_test----------
# 2026-07-23 16:22:44,122 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: prot_prot: 3367/6094(55.25%)
# 2026-07-23 16:22:44,122 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: intra_prot: 2727/6094(44.75%)
# 2026-07-23 16:22:44,122 [/home/daniel/BioKinema/protenix/data/dataset.py:631] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:22:44,124 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: prot_prot: 2/4(50.0%)
# 2026-07-23 16:22:44,126 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: intra_prot: 2/4(50.0%)
# 2026-07-23 16:22:44,126 [/home/daniel/BioKinema/protenix/data/dataset.py:637] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:22:44,126 [/home/daniel/BioKinema/protenix/data/dataset.py:639] INFO protenix.data.dataset: Final pdb ids: 606
# 2026-07-23 16:22:44,126 [/home/daniel/BioKinema/protenix/data/dataset.py:640] INFO protenix.data.dataset: ------------------------------
# token_crop_size 1000
# 2026-07-23 16:22:44,132 [/home/daniel/BioKinema/protenix/data/dataloader.py:418] INFO protenix.data.dataloader: train data size: 6, test size: {'lynxkite_test': 6}
# 2026-07-23 16:22:44,132 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Loading from ./checkpoints/BioKinema_atlas+misato+mdposit_sqrt.pt, strict: False
# /home/daniel/BioKinema/./runner/train.py:230: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, self.device)
# 2026-07-23 16:22:46,037 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-07-23 16:22:46,138 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Finish loading checkpoint, current step: 0
# 2026-07-23 16:22:46,196 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Loading from ./checkpoints/BioKinema_atlas+misato+mdposit_sqrt.pt, strict: False
# 2026-07-23 16:22:47,643 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-07-23 16:22:47,744 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Finish loading checkpoint, current step: 0
# Dumping embeddings mode on
# 2026-07-23 16:22:47,761 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Testing on lynxkite_test
# iterating target embeddings:  50%|█████     | 3/6 [00:27<00:26,  8.85s/it]2026-07-23 16:23:15,478 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 3] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-1__md idx 3:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:17,188 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 5] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-3__md idx 5:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:18,903 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 4] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-2__md idx 4:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# iterating target embeddings:  67%|██████▋   | 4/6 [00:40<00:21, 10.66s/it]2026-07-23 16:23:28,915 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 4] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-2__md idx 4:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:30,644 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 3] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-1__md idx 3:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:32,350 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 3] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-1__md idx 3:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:34,052 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 5] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-3__md idx 5:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:35,927 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 3] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-1__md idx 3:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:37,643 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 5] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-3__md idx 5:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# iterating target embeddings:  83%|████████▎ | 5/6 [00:59<00:13, 13.63s/it]2026-07-23 16:23:47,600 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 5] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-3__md idx 5:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:49,290 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 5] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-3__md idx 5:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:50,999 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 5] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-3__md idx 5:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:52,700 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 3] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-1__md idx 3:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# 2026-07-23 16:23:54,581 [/home/daniel/BioKinema/protenix/data/dataset.py:965] ERROR protenix.data.dataset: [skip data 3] index 4068 is out of bounds for axis 0 with size 4068 at test|2026-07-15__AT_MAS1_full_POSTSTERONE__MD1000-1__md idx 3:
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# Traceback (most recent call last):
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 837, in __getitem__
#     data = self.process_one(target_indices.index[0], return_atom_token_array=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1207, in process_one
#     ) = self.crop(
#         ^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/dataset.py", line 1338, in crop
#     return DataPipeline.crop(
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 290, in crop
#     msa_features = DataPipeline.get_msa_raw_features(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/data_pipeline.py", line 208, in get_msa_raw_features
#     msa_feats = msa_featurizer(
#                 ^^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 746, in __call__
#     msa_feats = self.tokenize(
#                 ^^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 771, in tokenize
#     msa_feats = tokenize_msa(
#                 ^^^^^^^^^^^^^
#   File "/home/daniel/BioKinema/protenix/data/msa_featurizer.py", line 880, in tokenize_msa
#     (msa_feats["asym_id"][idx], msa_feats["residue_index"][idx]): idx
#      ~~~~~~~~~~~~~~~~~~~~^^^^^
# IndexError: index 4068 is out of bounds for axis 0 with size 4068
# iterating target embeddings: 100%|██████████| 6/6 [01:15<00:00, 12.62s/it]
# Try to find the ccd cache data in the code directory for inference.
# 2026-07-23 16:24:09,357 [/home/daniel/BioKinema/./runner/train.py:117] INFO root: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-07-23 16:24:09,357 [/home/daniel/BioKinema/./runner/train.py:127] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-07-23 16:24:09,358 [/home/daniel/BioKinema/./runner/train.py:150] INFO root: Finished init ENV.
# env: DS_USE_CUTLASS_PYTHON_BINDINGS
# 2026-07-23 16:24:09,404 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Using run name: encode_lynxkite_train_20260723_162409, run dir: ./output_encode/encode_lynxkite_train_20260723_162409, checkpoint_dir: ./output_encode/encode_lynxkite_train_20260723_162409/checkpoints, prediction_dir: ./output_encode/encode_lynxkite_train_20260723_162409/predictions, structure_dir: ./output_encode/encode_lynxkite_train_20260723_162409/structures, error_dir: ./output_encode/encode_lynxkite_train_20260723_162409/errors
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# /home/daniel/BioKinema/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2026-07-23 16:24:15,756 [/home/daniel/BioKinema/protenix/model/loss.py:2114] INFO protenix.model.loss: [Loss.__init__] tica_dynamics_loss=True, alpha_tica_dynamics=0.1, tica_cfg=temperature: 2.0
# weight_autocorrelation: 0.0
# weight_population: 1.0
# weight_transition: 0.5
#
# 2026-07-23 16:24:15,756 [/home/daniel/BioKinema/protenix/data/dataset.py:2508] INFO protenix.data.dataset: Using train sets ['lynxkite_train']
# lynxkite_train /data/converted_trajectories/pairformer_emb_train None
# 2026-07-23 16:24:15,971 [/home/daniel/BioKinema/protenix/data/dataset.py:527] INFO protenix.data.dataset: #Rows in indices list: 14851
# 2026-07-23 16:24:15,971 [/home/daniel/BioKinema/protenix/data/dataset.py:614] INFO protenix.data.dataset: ---------- Dataset lynxkite_train----------
# 2026-07-23 16:24:16,042 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: prot_prot: 7882/14851(53.07%)
# 2026-07-23 16:24:16,042 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: intra_prot: 6969/14851(46.93%)
# 2026-07-23 16:24:16,042 [/home/daniel/BioKinema/protenix/data/dataset.py:631] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:24:16,046 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: prot_prot: 3/6(50.0%)
# 2026-07-23 16:24:16,049 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: intra_prot: 3/6(50.0%)
# 2026-07-23 16:24:16,050 [/home/daniel/BioKinema/protenix/data/dataset.py:637] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:24:16,050 [/home/daniel/BioKinema/protenix/data/dataset.py:639] INFO protenix.data.dataset: Final pdb ids: 1818
# 2026-07-23 16:24:16,050 [/home/daniel/BioKinema/protenix/data/dataset.py:640] INFO protenix.data.dataset: ------------------------------
# token_crop_size 1000
# --- WeightedMultiDataset Initialization ---
#   - Dataset 'lynxkite_train':
#     Dataset size: 18, Dataset Weight: 1.0
# lynxkite_train /data/converted_trajectories/pairformer_emb_train None
# 2026-07-23 16:24:16,257 [/home/daniel/BioKinema/protenix/data/dataset.py:527] INFO protenix.data.dataset: #Rows in indices list: 14851
# 2026-07-23 16:24:16,257 [/home/daniel/BioKinema/protenix/data/dataset.py:614] INFO protenix.data.dataset: ---------- Dataset lynxkite_train----------
# 2026-07-23 16:24:16,324 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: prot_prot: 7882/14851(53.07%)
# 2026-07-23 16:24:16,324 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: intra_prot: 6969/14851(46.93%)
# 2026-07-23 16:24:16,324 [/home/daniel/BioKinema/protenix/data/dataset.py:631] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:24:16,328 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: prot_prot: 3/6(50.0%)
# 2026-07-23 16:24:16,331 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: intra_prot: 3/6(50.0%)
# 2026-07-23 16:24:16,331 [/home/daniel/BioKinema/protenix/data/dataset.py:637] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:24:16,332 [/home/daniel/BioKinema/protenix/data/dataset.py:639] INFO protenix.data.dataset: Final pdb ids: 1818
# 2026-07-23 16:24:16,332 [/home/daniel/BioKinema/protenix/data/dataset.py:640] INFO protenix.data.dataset: ------------------------------
# token_crop_size 1000
# 2026-07-23 16:24:16,346 [/home/daniel/BioKinema/protenix/data/dataloader.py:418] INFO protenix.data.dataloader: train data size: 18, test size: {'lynxkite_train': 18}
# 2026-07-23 16:24:16,346 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Loading from ./checkpoints/BioKinema_atlas+misato+mdposit_sqrt.pt, strict: False
# /home/daniel/BioKinema/./runner/train.py:230: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, self.device)
# 2026-07-23 16:24:18,100 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-07-23 16:24:18,200 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Finish loading checkpoint, current step: 0
# 2026-07-23 16:24:18,259 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Loading from ./checkpoints/BioKinema_atlas+misato+mdposit_sqrt.pt, strict: False
# 2026-07-23 16:24:19,680 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-07-23 16:24:19,781 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Finish loading checkpoint, current step: 0
# Dumping embeddings mode on
# 2026-07-23 16:24:19,798 [/home/daniel/BioKinema/./runner/train.py:285] INFO root: Testing on lynxkite_train
# iterating target embeddings: 100%|██████████| 18/18 [01:16<00:00,  4.24s/it]

# %%
# %%bash
# bash train-lk.sh 0
# Out:
# Try to find the ccd cache data in the code directory for inference.
# 2026-07-23 16:25:43,660 [/home/daniel/BioKinema/runner/train.py:117] INFO root: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-07-23 16:25:43,660 [/home/daniel/BioKinema/runner/train.py:127] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-07-23 16:25:43,660 [/home/daniel/BioKinema/runner/train.py:150] INFO root: Finished init ENV.
# env: DS_USE_CUTLASS_PYTHON_BINDINGS
# 2026-07-23 16:25:43,707 [/home/daniel/BioKinema/runner/train.py:285] INFO root: Using run name: lynxkite_eval_steps0_20260723_162543, run dir: ./output_eval_steps0/lynxkite_eval_steps0_20260723_162543, checkpoint_dir: ./output_eval_steps0/lynxkite_eval_steps0_20260723_162543/checkpoints, prediction_dir: ./output_eval_steps0/lynxkite_eval_steps0_20260723_162543/predictions, structure_dir: ./output_eval_steps0/lynxkite_eval_steps0_20260723_162543/structures, error_dir: ./output_eval_steps0/lynxkite_eval_steps0_20260723_162543/errors
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# /home/daniel/BioKinema/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2026-07-23 16:25:49,877 [/home/daniel/BioKinema/protenix/model/loss.py:2114] INFO protenix.model.loss: [Loss.__init__] tica_dynamics_loss=True, alpha_tica_dynamics=0.1, tica_cfg=temperature: 2.0
# weight_autocorrelation: 0.0
# weight_population: 1.0
# weight_transition: 0.5
#
# 2026-07-23 16:25:49,877 [/home/daniel/BioKinema/protenix/data/dataset.py:2508] INFO protenix.data.dataset: Using train sets ['lynxkite_train']
# lynxkite_train /data/converted_trajectories/pairformer_emb_train None
# 2026-07-23 16:25:49,920 [/home/daniel/BioKinema/protenix/data/dataset.py:527] INFO protenix.data.dataset: #Rows in indices list: 14851
# 2026-07-23 16:25:49,920 [/home/daniel/BioKinema/protenix/data/dataset.py:614] INFO protenix.data.dataset: ---------- Dataset lynxkite_train----------
# 2026-07-23 16:25:49,986 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: prot_prot: 7882/14851(53.07%)
# 2026-07-23 16:25:49,986 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: intra_prot: 6969/14851(46.93%)
# 2026-07-23 16:25:49,986 [/home/daniel/BioKinema/protenix/data/dataset.py:631] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:25:49,990 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: prot_prot: 3/6(50.0%)
# 2026-07-23 16:25:49,993 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: intra_prot: 3/6(50.0%)
# 2026-07-23 16:25:49,994 [/home/daniel/BioKinema/protenix/data/dataset.py:637] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:25:49,994 [/home/daniel/BioKinema/protenix/data/dataset.py:639] INFO protenix.data.dataset: Final pdb ids: 1818
# 2026-07-23 16:25:49,994 [/home/daniel/BioKinema/protenix/data/dataset.py:640] INFO protenix.data.dataset: ------------------------------
# token_crop_size 2000
# --- WeightedMultiDataset Initialization ---
#   - Dataset 'lynxkite_train':
#     Dataset size: 18, Dataset Weight: 1.0
# lynxkite_test /data/converted_trajectories/pairformer_emb_test None
# 2026-07-23 16:25:50,023 [/home/daniel/BioKinema/protenix/data/dataset.py:527] INFO protenix.data.dataset: #Rows in indices list: 6094
# 2026-07-23 16:25:50,023 [/home/daniel/BioKinema/protenix/data/dataset.py:614] INFO protenix.data.dataset: ---------- Dataset lynxkite_test----------
# 2026-07-23 16:25:50,050 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: prot_prot: 3367/6094(55.25%)
# 2026-07-23 16:25:50,050 [/home/daniel/BioKinema/protenix/data/dataset.py:629] INFO protenix.data.dataset: intra_prot: 2727/6094(44.75%)
# 2026-07-23 16:25:50,050 [/home/daniel/BioKinema/protenix/data/dataset.py:631] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:25:50,052 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: prot_prot: 2/4(50.0%)
# 2026-07-23 16:25:50,053 [/home/daniel/BioKinema/protenix/data/dataset.py:636] INFO protenix.data.dataset: intra_prot: 2/4(50.0%)
# 2026-07-23 16:25:50,053 [/home/daniel/BioKinema/protenix/data/dataset.py:637] INFO protenix.data.dataset: ------------------------------
# 2026-07-23 16:25:50,054 [/home/daniel/BioKinema/protenix/data/dataset.py:639] INFO protenix.data.dataset: Final pdb ids: 606
# 2026-07-23 16:25:50,054 [/home/daniel/BioKinema/protenix/data/dataset.py:640] INFO protenix.data.dataset: ------------------------------
# token_crop_size 2000
# 2026-07-23 16:25:50,059 [/home/daniel/BioKinema/protenix/data/dataloader.py:418] INFO protenix.data.dataloader: train data size: 18, test size: {'lynxkite_test': 3}
# 2026-07-23 16:25:50,059 [/home/daniel/BioKinema/runner/train.py:285] INFO root: Loading from /home/daniel/BioKinema/checkpoints/BioKinema_atlas+misato+mdposit_sqrt.pt, strict: False
# /home/daniel/BioKinema/runner/train.py:230: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, self.device)
# 2026-07-23 16:25:51,719 [/home/daniel/BioKinema/runner/train.py:285] INFO root: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-07-23 16:25:51,817 [/home/daniel/BioKinema/runner/train.py:285] INFO root: Finish loading checkpoint, current step: 0
# 2026-07-23 16:25:51,834 [/home/daniel/BioKinema/runner/train.py:285] INFO root: Testing on lynxkite_test
#   0%|          | 0/3 [00:00<?, ?it/s]/home/daniel/BioKinema/protenix/model/layer_norm/layer_norm.py:50: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/daniel/BioKinema/protenix/openfold_local/model/primitives.py:215: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/daniel/BioKinema/protenix/openfold_local/model/primitives.py:215: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/daniel/BioKinema/protenix/model/layer_norm/layer_norm.py:50: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|████████�█| 1/1 [00:36<00:00, 36.21s/it]��█| 1/1 [00:36<00:00, 36.21s/it]
# /home/daniel/BioKinema/protenix/model/protenix.py:555: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
#  33%|███▎      | 1/3 [01:03<02:07, 63.88s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|████████�█| 1/1 [00:36<00:00, 36.11s/it]��█| 1/1 [00:36<00:00, 36.11s/it]
#  67%|██████▋   | 2/3 [01:54<00:56, 56.26s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|████████�█| 1/1 [00:36<00:00, 36.12s/it]��█| 1/1 [00:36<00:00, 36.12s/it]
# 100%|██████████| 3/3 [02:45<00:00, 55.19s/it]
# 2026-07-23 16:28:37,407 [/home/daniel/BioKinema/runner/train.py:285] INFO root: Step 0, eval lynxkite_test: {'lynxkite_test/acf_loss.avg': 0.042520477126042046,
#  'lynxkite_test/bond_loss.avg': 0.0,
#  'lynxkite_test/center_loss.avg': 0.0,
#  'lynxkite_test/lig_bond_loss.avg': 0.0,
#  'lynxkite_test/local_rmsf_loss.avg': 0.024228111530343693,
#  'lynxkite_test/loss.avg': 119.5700454711914,
#  'lynxkite_test/mse_loss.avg': 17.307616869608562,
#  'lynxkite_test/rel_rmsf_loss.avg': 0.1013497884074847,
#  'lynxkite_test/rmsf_loss.avg': 1.653952916463216,
#  'lynxkite_test/smooth_lddt_loss.avg': 0.29814376433690387,
#  'lynxkite_test/velocity_loss.avg': 2.333157261212667,
#  'lynxkite_test/weighted_acf_loss.avg': 0.0,
#  'lynxkite_test/weighted_bond_loss.avg': 0.0,
#  'lynxkite_test/weighted_center_loss.avg': 0.0,
#  'lynxkite_test/weighted_lig_bond_loss.avg': 0.0,
#  'lynxkite_test/weighted_local_rmsf_loss.avg': 0.7752995689709982,
#  'lynxkite_test/weighted_mse_loss.avg': 69.23046747843425,
#  'lynxkite_test/weighted_rel_rmsf_loss.avg': 3.2431932290395102,
#  'lynxkite_test/weighted_rmsf_loss.avg': 26.463246663411457,
#  'lynxkite_test/weighted_smooth_lddt_loss.avg': 1.1925750573476155,
#  'lynxkite_test/weighted_velocity_loss.avg': 18.665258089701336}
